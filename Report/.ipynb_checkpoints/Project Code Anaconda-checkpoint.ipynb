# %% [raw]
# ---
# title: "Project Code"
# subtitle: Anaconda
# author: Hoda Fakhari, Elena Llaguno Cantu, Luna Nguyen, and Kiara Villalobos-Hernandez
# date: 03/15/2023
# number-sections: true
# abstract: _This file contains the code for the project on Hotel Booking Cancellations, as part of the STAT303-2 course in Winter 2023_.
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     self-contained: true
#     font-size: 100%
#     toc-depth: 4
#     mainfont: serif
# jupyter: python3
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
import itertools
import time
from datetime import datetime

# %% [markdown]
# ## Data quality check / cleaning / preparation
#
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.** An example is given below.

# %%
# Reading files 
df = pd.read_csv("Hotel Reservations.csv")

# %% [markdown]
# ### Data quality check
# *By Hoda Fakhari & Luna Nguyen*

# %%
# Total number of observations
df.shape
# Out:
# (36275, 19)

# %%
# Identifying number of missing values
print('There are', df.isnull().sum().sum(), 'missing values in the hotel reservation dataset.')
# Out:
# There are 0 missing values in the hotel reservation dataset.

# %%
# Identifying variable types to select categorical variables
df.dtypes
# Out:
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %% [markdown]
# The code below visualizes the distribution of all the continuous variables in the dataset.

# %%
#...Distribution of continuous variables...#
df.drop(['required_car_parking_space', 'repeated_guest', 'arrival_month', 'arrival_year'], axis = 1).describe().T
# Out:
#                                         count        mean        std  min  \
# no_of_adults                          36275.0    1.844962   0.518715  0.0
# no_of_children                        36275.0    0.105279   0.402648  0.0
# no_of_weekend_nights                  36275.0    0.810724   0.870644  0.0
# no_of_week_nights                     36275.0    2.204300   1.410905  0.0
# lead_time                             36275.0   85.232557  85.930817  0.0
# arrival_date                          36275.0   15.596995   8.740447  1.0
# no_of_previous_cancellations          36275.0    0.023349   0.368331  0.0
# no_of_previous_bookings_not_canceled  36275.0    0.153411   1.754171  0.0
# avg_price_per_room                    36275.0  103.423539  35.089424  0.0
# no_of_special_requests                36275.0    0.619655   0.786236  0.0
#
#                                        25%    50%    75%    max
# no_of_adults                           2.0   2.00    2.0    4.0
# no_of_children                         0.0   0.00    0.0   10.0
# no_of_weekend_nights                   0.0   1.00    2.0    7.0
# no_of_week_nights                      1.0   2.00    3.0   17.0
# lead_time                             17.0  57.00  126.0  443.0
# arrival_date                           8.0  16.00   23.0   31.0
# no_of_previous_cancellations           0.0   0.00    0.0   13.0
# no_of_previous_bookings_not_canceled   0.0   0.00    0.0   58.0
# avg_price_per_room                    80.3  99.45  120.0  540.0
# no_of_special_requests                 0.0   0.00    1.0    5.0

# %%
#...Distribution of categorical variables...#
for column in df[['required_car_parking_space', 'repeated_guest', 'arrival_month', 'arrival_year', 'type_of_meal_plan', 'room_type_reserved', 'market_segment_type']].columns:
    display(pd.crosstab(index=df[column], columns='% observations', normalize='columns')*100)
# Out:
# col_0                       % observations
# required_car_parking_space
# 0                                96.901447
# 1                                 3.098553
# col_0           % observations
# repeated_guest
# 0                    97.436251
# 1                     2.563749
# col_0          % observations
# arrival_month
# 1                    2.795314
# 2                    4.697450
# 3                    6.500345
# 4                    7.542385
# 5                    7.161957
# 6                    8.829773
# 7                    8.049621
# 8                   10.511371
# 9                   12.711234
# 10                  14.657478
# 11                   8.215024
# 12                   8.328050
# col_0         % observations
# arrival_year
# 2017               17.957271
# 2018               82.042729
# col_0              % observations
# type_of_meal_plan
# Meal Plan 1             76.733287
# Meal Plan 2              9.110958
# Meal Plan 3              0.013784
# Not Selected            14.141971
# col_0               % observations
# room_type_reserved
# Room_Type 1              77.546520
# Room_Type 2               1.907650
# Room_Type 3               0.019297
# Room_Type 4              16.697450
# Room_Type 5               0.730531
# Room_Type 6               2.662991
# Room_Type 7               0.435562
# col_0                % observations
# market_segment_type
# Aviation                   0.344590
# Complementary              1.077877
# Corporate                  5.560303
# Offline                   29.022743
# Online                    63.994487

# %% [markdown]
# The code below assesses the distribution of the the response.

# %%
# Proportion of 0 and 1s in response
df.booking_status.value_counts(1)
# Out:
# Not_Canceled    0.672364
# Canceled        0.327636
# Name: booking_status, dtype: float64

# %%
# Visualizing proportion of 0s and 1s in response
sns.countplot(x = 'booking_status', data = df);

# %% [markdown]
# ### Data cleaning
# *By *
#
# From the data quality check we realized that:
#
# 1. Some of the columns that should have contained only numeric values, specifically <>, <>, and <> have special characters such as \*, #, %. We'll remove these characters, and convert the datatype of these columns to numeric.
#
# 2. Some of the columns have more than 60% missing values, and it is very difficult to impute their values, as the values seem to be missing at random with negligible association with other predictors. We'll remove such columns from the data.
#
# 3. The column `number_of_bedrooms` has some unreasonably high values such as 15. As our data consist of single-family homes in Evanston, we suspect that any value greater than 5 may be incorrect. We'll replace all values that are greater than 5 with an estimate obtained using the $K$-nearest neighbor approach.
#
# 4. The columns `house_price` has some unreasonably high values. We'll tag all values greater than 1 billion dollars as "potentially incorrect observation", to see if they distort our prediction / inference later on.
#
# The code below implements the above cleaning.

# %%
#...Code with comments...#

# %% [markdown]
# ### Data preparation
# *By Hoda Fakhari & *
#
# The following data preparation steps helped us to prepare our data for implementing various modeling / validation techniques:
#
# 1. We converted categorical predictors to dummy variables for Variable Selection and Lasso / Ridge regression models.
#
# 2. We derived some new predictors *(from existing predictors)* that intuitively seem to be helpuful to predict booking status.
#
# 2. We have shuffled the dataset to prepare it for K-fold cross validation.
#
# 3. We have created a standardized version of the dataset, as we will use it to develop Lasso / Ridge regression models.

# %%
######---------------Preparing Categorical Predictors----------------#########

# Convert categorical variables to dummies and append to df 
dummy_market = pd.get_dummies(df.market_segment_type)
dummy_month = pd.get_dummies(df.arrival_month)
dummy_meal = pd.get_dummies(df.type_of_meal_plan)
dummy_room = pd.get_dummies(df.room_type_reserved)

# Add dummy variables to df and drop 1 to avoid perfect multicollinearity in model 
df_dummy = pd.concat([df, dummy_market.drop('Aviation', axis = 1), dummy_month.drop(4, axis = 1), dummy_meal.drop('Meal Plan 3', axis = 1), dummy_room.drop('Room_Type 7', axis = 1)], axis = 1)
df_dummy.columns = df_dummy.columns.astype(str)

# Remove spaces from column names 
df_dummy.columns = df_dummy.columns.str.replace(' ', '')

# Convert month number to name in columns 
df_dummy.rename(columns={'1': 'January', '2': 'February', '3': 'March', 
                         '5': 'May', '6': 'June', '7': 'July', 
                        '8': 'August', '9': 'September', '10': 'October',
                        '11': 'November', '12': 'December'}, inplace=True)

# Mapping response to 0 (Not Canceled) and 1 (Canceled)
df_dummy['booking_status'] = df_dummy['booking_status'].map({'Canceled': 1, 'Not_Canceled': 0})

# %%
######---------------Creating new predictors----------------#########

#Creating number of bedrooms per unit floor area

#Creating ratio of bathrooms to bedrooms

#Creating ratio of carpet area to floor area

# %%
######-----------Shuffling the dataset for K-fold------------#########

# Split train and test data 
train, test = train_test_split(df_dummy, test_size=0.25, random_state=25, shuffle=True)

# %%
######-----Standardizing the dataset for Lasso / Ridge-------#########

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.**

# %% [markdown]
# ### Relationship between Predictors and Response
# *By Hoda Fakhari*
#
# The code below determines the correlation of continuous variables with each other and the response and visualizes the association of continuous and categorical variables with the response.

# %%
# Determining correlations between continuous predictors
plt.figure(figsize = (14,7));
sns.heatmap(df.drop(['required_car_parking_space', 'repeated_guest', 'arrival_month', 'arrival_year'], axis = 1).corr(), annot = True);

# %%
# Relationship between continuous variables and response
fig, ax = plt.subplots(3, 3, figsize=(16, 18));
plt.subplots_adjust(hspace = 0.4, wspace = 0.3);

sns.boxplot(data=df, x ='avg_price_per_room', y ='booking_status', ax=ax[0, 0]);
sns.boxplot(data=df, x ='no_of_special_requests', y ='booking_status', ax=ax[0, 1]).set(ylabel=None);
sns.boxplot(data=df, x ='no_of_previous_bookings_not_canceled', y ='booking_status', ax=ax[0, 2]).set(ylabel=None);
sns.boxplot(data=df, x ='no_of_previous_cancellations', y ='booking_status', ax=ax[1, 0]);
sns.boxplot(data=df, x ='lead_time', y ='booking_status', ax=ax[1, 1]).set(ylabel=None);
sns.boxplot(data=df, x ='no_of_week_nights', y ='booking_status', ax=ax[1, 2]).set(ylabel=None);
sns.boxplot(data=df, x ='no_of_weekend_nights', y ='booking_status', ax=ax[2, 0]);
sns.boxplot(data=df, x ='no_of_children', y ='booking_status', ax=ax[2, 1]).set(ylabel=None);
sns.boxplot(data=df, x ='no_of_adults', y ='booking_status', ax=ax[2, 2]).set(ylabel=None);

# %%
# Mapping response to 0 (Not Canceled) and 1 (Canceled)
df['booking_status'].replace(['Canceled', 'Not_Canceled'],[1, 0], inplace=True)

# %%
# Correlation of continuous variables with response
df.drop(['required_car_parking_space', 'repeated_guest', 'arrival_month', 'arrival_year'], axis = 1).corrwith(df.booking_status)
# Out:
# no_of_adults                            0.086920
# no_of_children                          0.033078
# no_of_weekend_nights                    0.061563
# no_of_week_nights                       0.092996
# lead_time                               0.438538
# arrival_date                            0.010629
# no_of_previous_cancellations           -0.033728
# no_of_previous_bookings_not_canceled   -0.060179
# avg_price_per_room                      0.142569
# no_of_special_requests                 -0.253070
# booking_status                          1.000000
# dtype: float64

# %%
# Relationship between categorical variables and response
fig, ax = plt.subplots(4, 2, figsize=(16, 18));
plt.subplots_adjust(hspace = 0.4, wspace = 0.3);

sns.countplot(data=df, x ='repeated_guest', hue="booking_status", ax=ax[0, 0]);
sns.countplot(data=df, x='market_segment_type',hue='booking_status', ax=ax[0, 1]);
sns.countplot(data=df, x="arrival_month", hue="booking_status", ax=ax[1,0]);
sns.countplot(data=df, x="arrival_year",   hue="booking_status", ax=ax[1,1]);
sns.countplot(data=df, x="type_of_meal_plan",   hue="booking_status", ax=ax[2,0]);
sns.countplot(data=df, x="room_type_reserved",   hue="booking_status", ax=ax[2,1]);
sns.countplot(data=df, x="required_car_parking_space",   hue="booking_status", ax=ax[3,0]);

# %% [markdown]
# ### Binning of Continuous Variables
# *By Hoda Fakhari*
#
# Highly correlated continuous/numeric variables were binned and plotted to assess the use of transformations in the models.

# %%
# Lead time distribution
sns.histplot(df.lead_time);

# %%
# Lead time
binned_lead = pd.qcut(df['lead_time'],25,retbins=True)
df['lead_binned'] = binned_lead[0]

lead_data = df.groupby('lead_binned')['booking_status'].agg([('booking_percent','mean'),('nobs','count')]).reset_index(drop=False);
sns.lineplot(x = lead_data.index, y= lead_data['booking_percent']);
plt.xlabel('Lead Time Binned');

# %%
# Average Price per room distribution
sns.histplot(df.avg_price_per_room);

# %%
# Average Price per room
binned_price = pd.qcut(df['avg_price_per_room'],25,retbins=True)
df['price_binned'] = binned_price[0]

price_data = df.groupby('price_binned')['booking_status'].agg([('booking_percent','mean'),('nobs','count')]).reset_index(drop=False);
sns.lineplot(x = price_data.index, y= price_data['booking_percent']);
plt.xlabel('Average Price Per Room Binned');

# %%
# Number of Special Requests Distribution
sns.histplot(df.no_of_special_requests);

# %%
# Number of Special Requests
special_data = df.groupby('no_of_special_requests')['booking_status'].agg([('booking_percent','mean'),('nobs','count')]).reset_index(drop=False)
sns.lineplot(x = special_data.index, y= special_data['booking_percent']);
plt.xlabel('Number of Special Requests Binned');

# %% [markdown]
# ### Autocorrelation
# *By Luna Nguyen*

# %%
# Checking for the number of reservations cancelled and not cancelled every month
monthly_cancel = df.groupby(df.arrival_month).booking_status.value_counts()

# Creating a dataframe with the number of reservations cancelled and not cancelled for every month
monthly_cancel = pd.DataFrame({'Did not cancel': [990, 1274, 1658, 1741, 1650, 1912, 1606, 2325, 3073, 3437, 2105, 2619],
                   'Cancelled': [24, 430, 700, 995, 948, 1291, 1314, 1488, 1538, 1880, 875, 402]}, 
                  index=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec'])

# %%
# Create a dataframe wiht the percentage of reservations cancelled and not cancelled for every month
monthly_cancel_percent = monthly_cancel.copy()
monthly_cancel_percent['Total'] = monthly_cancel_percent['Did not cancel'] + monthly_cancel_percent['Cancelled']
monthly_cancel_percent['Did not cancel percent'] = monthly_cancel_percent['Did not cancel']/monthly_cancel_percent['Total']
monthly_cancel_percent['Cancel percent'] = monthly_cancel_percent['Cancelled']/monthly_cancel_percent['Total']
monthly_cancel_percent = monthly_cancel_percent.drop(['Did not cancel', 'Cancelled', 'Total'], axis = 1)

# %%
# Count of cancellations by month
monthly_cancel.plot(kind='bar', stacked=True, color=['purple', 'skyblue'])
plt.ylabel("Reservation Count")
plt.title("Reservation based on month")
plt.show()

# %%
# Proportion of cancellations by month
monthly_cancel_percent.plot(kind='bar', stacked=True, color=['purple', 'skyblue'])
plt.ylabel("Percentage")
plt.title('Cancellation percentage based on month')
plt.show()

# %% [markdown]
# ## Developing the model

# %% [markdown]
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.**

# %%
#Function to compute confusion matrix and prediction accuracy on test/train data
def confusion_matrix_data(data,actual_values,model,cutoff=0.5):
#Predict the values using the Logit model
    pred_values = model.predict(data)
# Specify the bins
    bins=np.array([0,cutoff,1])
#Confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
# Calculate the accuracy
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    fnr = (cm[1,0])/(cm[1,0]+cm[1,1])
    precision = (cm[1,1])/(cm[0,1]+cm[1,1])
    fpr = (cm[0,1])/(cm[0,0]+cm[0,1])
    tpr = (cm[1,1])/(cm[1,0]+cm[1,1])
    fpr_roc, tpr_roc, auc_thresholds = roc_curve(actual_values, pred_values)
    auc_value = (auc(fpr_roc, tpr_roc))# AUC of ROC
    sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
    plt.ylabel("Actual Values")
    plt.xlabel("Predicted Values")
    print("Classification accuracy = {:.1%}".format(accuracy))
    print("Precision = {:.1%}".format(precision))
    print("TPR or Recall = {:.1%}".format(tpr))
    print("FNR = {:.1%}".format(fnr))
    print("FPR = {:.1%}".format(fpr))
    print("ROC-AUC = {:.1%}".format(auc_value))

# %% [markdown]
# ### Model 1) Baseline Model
# *By Kiara?*

# %%
# Model 1) Baseline Model
logit_model = sm.logit(formula = 'booking_status ~ no_of_adults + no_of_children  + no_of_weekend_nights + no_of_week_nights + type_of_meal_plan + required_car_parking_space + room_type_reserved +lead_time  + market_segment_type +repeated_guest + no_of_previous_cancellations + avg_price_per_room  + no_of_special_requests', data = train).fit()
logit_model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.422758
#          Iterations: 35
# /Users/linhnganguyen/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         booking_status   No. Observations:                27206
# Model:                          Logit   Df Residuals:                    27182
# Method:                           MLE   Df Model:                           23
# Date:                Sun, 12 Mar 2023   Pseudo R-squ.:                  0.3301
# Time:                        04:39:00   Log-Likelihood:                -11502.
# converged:                      False   LL-Null:                       -17170.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                               -3.0608      0.247    -12.408      0.000      -3.544      -2.577
# type_of_meal_plan[T.Meal Plan 2]         0.0878      0.062      1.424      0.154      -0.033       0.209
# type_of_meal_plan[T.Meal Plan 3]         3.4190   6.34e+04   5.39e-05      1.000   -1.24e+05    1.24e+05
# type_of_meal_plan[T.Not Selected]        0.2763      0.051      5.440      0.000       0.177       0.376
# room_type_reserved[T.Room_Type 2]       -0.3331      0.128     -2.602      0.009      -0.584      -0.082
# room_type_reserved[T.Room_Type 3]        0.6164      1.596      0.386      0.699      -2.512       3.745
# room_type_reserved[T.Room_Type 4]       -0.2370      0.052     -4.593      0.000      -0.338      -0.136
# room_type_reserved[T.Room_Type 5]       -0.8168      0.201     -4.069      0.000      -1.210      -0.423
# room_type_reserved[T.Room_Type 6]       -1.0549      0.146     -7.218      0.000      -1.341      -0.768
# room_type_reserved[T.Room_Type 7]       -1.3978      0.296     -4.721      0.000      -1.978      -0.817
# market_segment_type[T.Complementary]   -21.7108   6679.484     -0.003      0.997   -1.31e+04    1.31e+04
# market_segment_type[T.Corporate]        -1.0148      0.251     -4.035      0.000      -1.508      -0.522
# market_segment_type[T.Offline]          -2.0496      0.241     -8.508      0.000      -2.522      -1.577
# market_segment_type[T.Online]           -0.1827      0.238     -0.768      0.442      -0.649       0.283
# no_of_adults                             0.0873      0.036      2.393      0.017       0.016       0.159
# no_of_children                           0.1514      0.057      2.666      0.008       0.040       0.263
# no_of_weekend_nights                     0.1278      0.019      6.671      0.000       0.090       0.165
# no_of_week_nights                        0.0417      0.012      3.521      0.000       0.018       0.065
# required_car_parking_space              -1.7151      0.141    -12.185      0.000      -1.991      -1.439
# lead_time                                0.0159      0.000     64.764      0.000       0.015       0.016
# repeated_guest                          -2.3456      0.446     -5.257      0.000      -3.220      -1.471
# no_of_previous_cancellations             0.2366      0.066      3.599      0.000       0.108       0.365
# avg_price_per_room                       0.0197      0.001     28.802      0.000       0.018       0.021
# no_of_special_requests                  -1.5371      0.029    -52.521      0.000      -1.594      -1.480
# ========================================================================================================
# """

# %%
# Evaluating Model 1 on train data
confusion_matrix_data(train, train.booking_status, logit_model, cutoff = 0.4)
# Out:
# Classification accuracy = 79.6%
# Precision = 67.7%
# TPR or Recall = 71.4%
# FNR = 28.6%
# FPR = 16.4%
# ROC-AUC = 86.4%

# %%
# Evaluating Model 1 on test data
confusion_matrix_data(test, test.booking_status, logit_model, cutoff = 0.4)
# Out:
# Classification accuracy = 78.7%
# Precision = 67.7%
# TPR or Recall = 68.9%
# FNR = 31.1%
# FPR = 16.5%
# ROC-AUC = 85.4%

# %%
#Predict the values using the Model 1 (Baseline)
pred_values_1 = logit_model.predict(test)

# %% [markdown]
# ### Model 2) EDA-Based
# *By Hoda Fakhari*

# %%
# Model 2) EDA-Based Logit Model - By Hoda Fakhari
eda_model = sm.logit('booking_status ~ np.log(lead_time+1) + np.log(avg_price_per_room+1) + no_of_special_requests', data = train).fit()
eda_model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.478240
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         booking_status   No. Observations:                27206
# Model:                          Logit   Df Residuals:                    27202
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 12 Mar 2023   Pseudo R-squ.:                  0.2422
# Time:                        04:39:03   Log-Likelihood:                -13011.
# converged:                       True   LL-Null:                       -17170.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -13.4977      0.288    -46.883      0.000     -14.062     -12.933
# np.log(lead_time + 1)              0.8436      0.015     57.079      0.000       0.815       0.873
# np.log(avg_price_per_room + 1)     2.1477      0.058     37.061      0.000       2.034       2.261
# no_of_special_requests            -1.0933      0.024    -45.054      0.000      -1.141      -1.046
# ==================================================================================================
# """

# %%
# Evaluating Model 2 on train data
confusion_matrix_data(train, train.booking_status, eda_model, cutoff = 0.4)
# Out:
# Classification accuracy = 75.6%
# Precision = 60.9%
# TPR or Recall = 70.5%
# FNR = 29.5%
# FPR = 21.9%
# ROC-AUC = 82.2%

# %%
# Evaluating Model 2 on test data
confusion_matrix_data(test, test.booking_status, eda_model, cutoff = 0.4)
# Out:
# Classification accuracy = 74.9%
# Precision = 60.9%
# TPR or Recall = 68.7%
# FNR = 31.3%
# FPR = 22.0%
# ROC-AUC = 81.1%

# %%
#Predict the values using the EDA-Based Logit model
pred_values_2 = eda_model.predict(test)

# %% [markdown]
# ### Model 3) Variable Selection
# *By Hoda Fakhari*

# %%
# Model 3) Forward/Backward Selection Model (Produced same model with 18 predictors based on BIC criterion)

# Continuous and categorical predictors (except market_segment_type, type_of_meal_plan, room_type_reserved)
X = train[['no_of_adults', 'no_of_children','no_of_weekend_nights','no_of_week_nights',
           'required_car_parking_space','lead_time','arrival_year','arrival_date','repeated_guest', 
           'no_of_previous_cancellations','no_of_previous_bookings_not_canceled','avg_price_per_room', 
           'no_of_special_requests', 'January','February', 'March', 'May', 'June', 'July', 
           'August', 'September','October', 'November', 'December']]

#Function to develop a model based on all predictors in predictor_subset
def processSubset(predictor_subset):
    # Fit model on feature_set and calculate BIC
    model = sm.logit('booking_status~' + '+'.join(predictor_subset), data = train).fit()
    BIC = model.bic
    return {"model":model, "BIC":BIC}

#Function to find the best predictor out of p-k predictors and add it to the model containing the k predictors
def forward(predictors):

    # Pull out predictors we still need to process
    remaining_predictors = [p for p in X.columns if p not in predictors]
    
    results = []
    
    for p in remaining_predictors:
        results.append(processSubset(predictors+[p]))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the lowest BIC
    best_model = models.loc[models['BIC'].argmin()]
    
    # Return the best model, along with some other useful information about the model
    return best_model

def forward_selection():
    models_best = pd.DataFrame(columns=["BIC", "model"])

    predictors = []

    for i in range(1,len(X.columns)+1):    
        models_best.loc[i] = forward(predictors)
        predictors = list(models_best.loc[i]["model"].params.index[1:])

    return models_best

models_best = forward_selection()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.627206
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.630572
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.629293
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626756
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626106
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535235
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.613451
#          Iterations 17
# Optimization terminated successfully.
#          Current function value: 0.631083
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.622996
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.630324
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.624337
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.620578
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593321
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.622422
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.630380
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631056
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.630907
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.630066
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.628478
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629885
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.631114
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.630769
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.630855
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.621856
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533636
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533476
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.534276
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.534741
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.532298
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525422
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.535217
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.532028
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.535065
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.532738
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.514934
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503972
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.530536
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.534885
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.534152
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.534943
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.535035
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.534852
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.534774
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.535038
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.535134
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.535234
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.525795
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.499844
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.501843
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.502703
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.502288
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.489761
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.503924
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500265
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.503719
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.501312
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.471028
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497996
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.503867
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503288
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503787
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503948
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503167
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503048
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503832
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503918
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495238
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469982
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.471025
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468107
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469775
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468312
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462743
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.470987
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469313
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.470991
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.469977
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.467685
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.469256
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468742
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.471021
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470884
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470691
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470868
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469556
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470954
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470168
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.465285
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.461682
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462742
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.460399
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.461662
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.459942
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462708
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.460957
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462696
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.461447
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.458474
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.461828
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.461530
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462557
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462142
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462475
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462398
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462413
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462590
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.461887
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.457774
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.456344
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.457737
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.455340
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.456343
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.454920
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.457683
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.456017
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.457720
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.456507
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.453155
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.457085
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.456866
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.457442
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.456865
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.457665
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.457620
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.457149
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.457757
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.457184
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.451870
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.453078
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450739
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.451756
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450366
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.453060
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.451394
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.453128
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.451886
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.452707
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.452530
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.452703
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.452034
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.453088
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.453043
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.452475
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.453153
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.452729
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.449071
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450280
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.448033
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.449090
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450271
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.448892
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.450347
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.449344
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.449893
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.449670
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.449889
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.449158
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450276
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450162
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.449608
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.450366
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.449956
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446986
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447981
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.447298
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447974
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446665
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.448016
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447101
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.447585
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.447373
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447577
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.447090
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447986
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447886
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.447300
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.448033
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.447530
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.445799
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446607
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446006
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446611
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446439
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446638
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.446236
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446055
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446218
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445720
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446618
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446527
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445990
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446665
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446168
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.444986
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445684
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445083
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445672
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445500
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445694
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.445380
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445253
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.445064
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445711
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445659
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444805
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445702
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445336
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444142
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444795
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444202
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444744
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444590
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444783
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.444500
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444422
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443909
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444800
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444802
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444658
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444530
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443316
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443907
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443296
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443848
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443701
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443888
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.443694
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443660
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443862
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443899
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443604
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443732
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442741
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443295
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443229
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443084
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443275
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.443073
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443078
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443240
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443283
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443046
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443139
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442714
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442682
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442544
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442722
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442494
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442570
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442671
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442717
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442556
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442542
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442476
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442447
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442299
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442476
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442233
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442444
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442480
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442349
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442227
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442206
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442165
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442029
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442210
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441854
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442205
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442226
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442149
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441842
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441808
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441652
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441837
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441853
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441849
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441829
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441640
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441604
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441607
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441650
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441646
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441629
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441594
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441559
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441603
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441599
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441583
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441548
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441558
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441553
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441537
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441529
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441530
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441537
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441521
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441529
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441520
#          Iterations 12

# %%
def best_sub_plots():
    plt.figure(figsize=(20,10))
    plt.rcParams.update({'font.size': 18, 'lines.markersize': 10})

    # Set up a 2x2 grid so we can look at 4 plots at once
    plt.subplot(2, 2, 1)


    # AIC and BIC 
    aic = models_best.apply(lambda row: row[1].aic, axis=1)

    plt.subplot(2, 2, 1)
    plt.plot(aic)
    plt.plot(1+aic.argmin(), aic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('AIC')

    bic = models_best.apply(lambda row: row[1].bic, axis=1)

    plt.subplot(2, 2, 2)
    plt.plot(bic)
    plt.plot(1+bic.argmin(), bic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('BIC')

best_sub_plots()

# %%
best_forward_model = models_best.loc[18,'model']
best_forward_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         booking_status   No. Observations:                27206
# Model:                          Logit   Df Residuals:                    27187
# Method:                           MLE   Df Model:                           18
# Date:                Sun, 12 Mar 2023   Pseudo R-squ.:                  0.3002
# Time:                        04:39:31   Log-Likelihood:                -12016.
# converged:                       True   LL-Null:                       -17170.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                    -1871.9280    108.161    -17.307      0.000   -2083.920   -1659.936
# lead_time                        0.0128      0.000     55.754      0.000       0.012       0.013
# no_of_special_requests          -1.1974      0.027    -45.056      0.000      -1.250      -1.145
# avg_price_per_room               0.0189      0.001     32.373      0.000       0.018       0.020
# arrival_year                     0.9258      0.054     17.269      0.000       0.821       1.031
# December                        -1.3421      0.081    -16.521      0.000      -1.501      -1.183
# January                         -2.5764      0.246    -10.456      0.000      -3.059      -2.093
# required_car_parking_space      -1.4755      0.138    -10.702      0.000      -1.746      -1.205
# no_of_weekend_nights             0.1627      0.019      8.745      0.000       0.126       0.199
# repeated_guest                  -2.4011      0.409     -5.877      0.000      -3.202      -1.600
# June                            -0.3645      0.056     -6.483      0.000      -0.475      -0.254
# September                       -0.3325      0.054     -6.176      0.000      -0.438      -0.227
# May                             -0.3013      0.061     -4.931      0.000      -0.421      -0.182
# no_of_week_nights                0.0619      0.012      5.308      0.000       0.039       0.085
# no_of_adults                     0.1847      0.033      5.513      0.000       0.119       0.250
# February                         0.3980      0.079      5.027      0.000       0.243       0.553
# November                         0.3019      0.066      4.607      0.000       0.173       0.430
# March                            0.2974      0.065      4.563      0.000       0.170       0.425
# no_of_previous_cancellations     0.2785      0.090      3.101      0.002       0.102       0.454
# ================================================================================================
# """

# %%
def backward(predictors):
    
    tic = time.time()
    
    results = []
    
    for combo in itertools.combinations(predictors, len(predictors)-1):
        results.append(processSubset(combo))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the highest RSS
    best_model = models.loc[models['BIC'].argmin()]
    
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors)-1, "predictors in", (toc-tic), "seconds.")
    
    # Return the best model, along with some other useful information about the model
    return best_model

def backward_selection():
    models_best = pd.DataFrame(columns=["BIC", "model"], index = range(1,len(X.columns)))

    tic = time.time()
    predictors = X.columns
    models_best.loc[len(predictors)] = processSubset(predictors)
    
    while(len(predictors) > 1):  
        models_best.loc[len(predictors)-1] = backward(predictors)
        predictors = models_best.loc[len(predictors)-1]["model"].params.index[1:]

    toc = time.time()
    print("Total elapsed time:", (toc-tic), "seconds.")
    return models_best

models_best = backward_selection()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441520
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.445820
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441725
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441543
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441987
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441521
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441529
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442069
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441878
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441713
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441802
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.445410
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.488635
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.458388
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441565
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441747
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442113
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.441565
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.446732
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.513841
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.444195
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442033
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442897
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441528
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442052
#          Iterations 12
# Processed  24 models on 23 predictors in 4.248081922531128 seconds.
# Optimization terminated successfully.
#          Current function value: 0.446928
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441803
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441547
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442174
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441529
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442252
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441976
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441782
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441864
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.445635
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.488788
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.458616
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441566
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441750
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442114
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.441566
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.446958
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.515179
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.444210
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442033
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442897
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441530
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442052
#          Iterations 12
# Processed  23 models on 22 predictors in 4.87758207321167 seconds.
# Optimization terminated successfully.
#          Current function value: 0.447241
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441861
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441548
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442216
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442294
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441991
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441835
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441910
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.445675
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.488880
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.458621
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441574
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441759
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442122
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.441575
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.446978
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.515670
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.444217
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442038
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442901
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441537
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442060
#          Iterations 12
# Processed  22 models on 21 predictors in 3.8805439472198486 seconds.
# Optimization terminated successfully.
#          Current function value: 0.447251
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441867
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441559
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442255
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442325
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442011
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441848
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441926
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.445677
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.489076
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.462522
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441583
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441768
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442131
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.441584
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.446979
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.516013
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.444226
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442049
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442920
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442062
#          Iterations 12
# Processed  21 models on 20 predictors in 3.20031476020813 seconds.
# Optimization terminated successfully.
#          Current function value: 0.447414
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441954
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442276
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442336
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442012
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441919
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441993
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.445684
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.489347
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.462523
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.441604
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441791
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442158
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.441607
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.447423
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.516393
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.444229
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442084
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442945
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.442112
#          Iterations 12
# Processed  20 models on 19 predictors in 3.0691452026367188 seconds.
# Optimization terminated successfully.
#          Current function value: 0.447461
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442000
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442324
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442382
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442058
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441965
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442037
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445720
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.489437
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.462603
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441808
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442843
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441652
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447456
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.516545
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.444278
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442128
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442989
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442160
#          Iterations 11
# Processed  19 models on 18 predictors in 3.489362955093384 seconds.
# Optimization terminated successfully.
#          Current function value: 0.447467
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442036
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442361
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442431
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442104
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442029
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442102
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445762
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.489453
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462669
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.441854
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442893
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447514
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.516665
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.444326
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442170
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443059
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442214
#          Iterations 11
# Processed  18 models on 17 predictors in 2.350153923034668 seconds.
# Optimization terminated successfully.
#          Current function value: 0.447692
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442233
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442569
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442640
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442311
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442227
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442306
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445922
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.489688
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462855
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.442900
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447733
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.517009
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.444546
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442369
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443266
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442432
#          Iterations 11
# Processed  17 models on 16 predictors in 2.432612180709839 seconds.
# Optimization terminated successfully.
#          Current function value: 0.448616
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442494
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443075
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443232
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442851
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442542
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446655
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.490596
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462985
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443297
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.448951
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.519286
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.444877
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442782
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443609
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442859
#          Iterations 11
# Processed  16 models on 15 predictors in 2.7454590797424316 seconds.
# Optimization terminated successfully.
#          Current function value: 0.449262
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443480
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443668
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443239
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.442741
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447129
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.490596
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.462987
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.443568
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.449283
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.519334
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.445173
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443076
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443812
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443073
#          Iterations 11
# Processed  15 models on 14 predictors in 2.867654323577881 seconds.
# Optimization terminated successfully.
#          Current function value: 0.449759
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443776
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444034
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443579
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447607
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.491100
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.463133
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.443825
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.450107
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.521010
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.445398
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443316
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444062
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443296
#          Iterations 11
# Processed  14 models on 13 predictors in 3.1812667846679688 seconds.
# Optimization terminated successfully.
#          Current function value: 0.450117
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444413
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444758
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444202
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.448298
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.491178
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.466997
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444508
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.450718
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.523696
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.445923
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.443909
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.444722
#          Iterations 11
# Processed  13 models on 12 predictors in 2.0414609909057617 seconds.
# Optimization terminated successfully.
#          Current function value: 0.450485
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445064
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445402
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.444805
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.448927
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.491349
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.467718
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.445187
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.451441
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.527740
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446605
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445766
#          Iterations 11
# Processed  12 models on 11 predictors in 1.4582688808441162 seconds.
# Optimization terminated successfully.
#          Current function value: 0.450991
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.445720
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.445990
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.449610
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.491627
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.467958
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.446106
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.451859
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.528578
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.447438
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446723
#          Iterations 10
# Processed  11 models on 10 predictors in 1.0792820453643799 seconds.
# Optimization terminated successfully.
#          Current function value: 0.451483
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.446665
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450441
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.492632
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.467963
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.447090
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.454343
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.528588
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.448246
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.447690
#          Iterations 10
# Processed  10 models on 9 predictors in 0.8436880111694336 seconds.
# Optimization terminated successfully.
#          Current function value: 0.452092
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.451198
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.492817
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.468451
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.448033
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.454658
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.528778
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.449118
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.448892
#          Iterations 11
# Processed  9 models on 8 predictors in 0.7137398719787598 seconds.
# Optimization terminated successfully.
#          Current function value: 0.453492
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.452576
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.494057
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.471332
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.455994
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.533331
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450739
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.450366
#          Iterations 10
# Processed  8 models on 7 predictors in 0.5567829608917236 seconds.
# Optimization terminated successfully.
#          Current function value: 0.455739
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.454920
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.494915
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.472961
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.458929
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.536213
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.453155
#          Iterations 11
# Processed  7 models on 6 predictors in 0.5502488613128662 seconds.
# Optimization terminated successfully.
#          Current function value: 0.458474
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.457774
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.499323
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.474974
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.461581
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.540176
#          Iterations 10
# Processed  6 models on 5 predictors in 0.5443992614746094 seconds.
# Optimization terminated successfully.
#          Current function value: 0.462743
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.503079
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.482870
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.465285
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.550044
#          Iterations 10
# Processed  5 models on 4 predictors in 0.34085869789123535 seconds.
# Optimization terminated successfully.
#          Current function value: 0.509551
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.489761
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.471028
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554652
#          Iterations 10
# Processed  4 models on 3 predictors in 0.31302905082702637 seconds.
# Optimization terminated successfully.
#          Current function value: 0.514934
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503972
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.571389
#          Iterations 6
# Processed  3 models on 2 predictors in 0.14745593070983887 seconds.
# Optimization terminated successfully.
#          Current function value: 0.535235
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593321
#          Iterations 6
# Processed  2 models on 1 predictors in 0.07818913459777832 seconds.
# Total elapsed time: 45.20419788360596 seconds.

# %%
best_sub_plots()

# %%
# Evaluating Model 3 on train data
confusion_matrix_data(train, train.booking_status, best_forward_model, cutoff = 0.4)
# Out:
# Classification accuracy = 78.5%
# Precision = 66.4%
# TPR or Recall = 68.7%
# FNR = 31.3%
# FPR = 16.8%
# ROC-AUC = 84.8%

# %%
# Evaluating Model 3 on test data
confusion_matrix_data(test, test.booking_status, best_forward_model, cutoff = 0.4)
# Out:
# Classification accuracy = 77.3%
# Precision = 66.1%
# TPR or Recall = 65.2%
# FNR = 34.8%
# FPR = 16.7%
# ROC-AUC = 83.7%

# %%
#Predict the values using the best Forward/Backward model
pred_values_3 = best_forward_model.predict(test)

# %% [markdown]
# ### Model 4) KNN
# *By Hoda Fakhari*

# %%
# Model 4) KNN

# Split train and test datasets
y = df_dummy.booking_status
X = df_dummy.drop(['booking_status', 'Booking_ID', 'type_of_meal_plan', 'market_segment_type', 'arrival_month', 'room_type_reserved'], axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0, shuffle=True)

# KNN with all predictors
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier().fit(X_train, y_train)

# %%
# Evaluating Model 4 on train data
confusion_matrix_data(X_train, y_train, knn, cutoff = 0.4)
# Out:
# /Users/linhnganguyen/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# Classification accuracy = 86.8%
# Precision = 84.5%
# TPR or Recall = 72.8%
# FNR = 27.2%
# FPR = 6.5%
# ROC-AUC = 83.2%

# %%
# Evaluating Model 4 on test data
confusion_matrix_data(X_test, y_test, knn, cutoff = 0.4)
# Out:
# /Users/linhnganguyen/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# Classification accuracy = 79.6%
# Precision = 73.6%
# TPR or Recall = 59.9%
# FNR = 40.1%
# FPR = 10.7%
# ROC-AUC = 74.6%

# %%
#Predict the values using the Model 4 (KNN)
pred_values_4 = knn.predict(X_test)
# Out:
# /Users/linhnganguyen/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# ### Model 5) KNN + Variable Selection
# *By Hoda Fakhari*

# %%
# Model 5) KNN + Variable Selection 

# KNN with 18 features selected from forward/backward selection 
y = df_dummy.booking_status
X = df_dummy[['no_of_adults', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space',
            'lead_time', 'arrival_year', 'repeated_guest', 'no_of_previous_cancellations', 
            'avg_price_per_room', 'no_of_special_requests', 'December', 'January',
             'June', 'September', 'May', 'February', 'November', 'March']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0, shuffle=True)
knn_var = KNeighborsClassifier().fit(X_train, y_train)

# %%
# Evaluating Model 5 on train data
confusion_matrix_data(X_train, y_train, knn_var, cutoff = 0.4)

# %%
# Evaluating Model 5 on test data
confusion_matrix_data(X_test, y_test, knn_var, cutoff = 0.4)

# %%
#Predict the values using the KNN +variable selection model
pred_values_5 = knn_var.predict(X_test)

# %% [markdown]
# ### Model 6) Ridge
# *By Hoda Fakhari*

# %%
alphas = 10**np.linspace(10,-2,200)*0.5

#Finding the ridge regression coefficients for increasing values of the tuning parameter
coefs = []
for a in alphas:        
    ridge = Ridge(alpha = a)
    ridge.fit(Xstd, y)
    coefs.append(ridge.coef_)

# %%
# Model 6) Ridge

y = train.booking_status

#Standardizing predictors so that each of them have zero mean and unit variance

#Filtering all predictors
X = train.loc[:,['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
       'no_of_week_nights', 'required_car_parking_space','lead_time', 'arrival_year', 
       'arrival_date', 'repeated_guest','no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
       'avg_price_per_room', 'no_of_special_requests', 'Complementary', 'Corporate', 
        'Offline', 'Online', 'January','February', 'March', 'May', 'June', 'July', 'August', 'September',
       'October', 'November', 'December', 'MealPlan1', 'MealPlan2','NotSelected', 
        'Room_Type1', 'Room_Type2', 'Room_Type3', 'Room_Type4','Room_Type5', 'Room_Type6']]

#Defining a scaler object
scaler = StandardScaler()

scaler.fit(X)

#Using the scaler object (or the values of mean and variance stored in it) to standardize X (or train data)
Xstd = scaler.transform(X)

#Filtering all predictors in test dataset
Xtest = test.loc[:,['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
       'no_of_week_nights', 'required_car_parking_space',
       'lead_time', 'arrival_year', 'arrival_date', 'repeated_guest',
       'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
       'avg_price_per_room', 'no_of_special_requests', 
       'Complementary', 'Corporate', 'Offline', 'Online', 'January',
       'February', 'March', 'May', 'June', 'July', 'August', 'September',
       'October', 'November', 'December', 'MealPlan1', 'MealPlan2',
       'NotSelected', 'Room_Type1', 'Room_Type2', 'Room_Type3', 'Room_Type4',
       'Room_Type5', 'Room_Type6']]

#Standardizing test data
Xtest_std = scaler.transform(Xtest)

#Visualizing the shrinkage in ridge regression coefficients with increasing values of the tuning parameter lambda
plt.xlabel('xlabel', fontsize=18)
plt.ylabel('ylabel', fontsize=18)
plt.plot(alphas, coefs)
plt.xscale('log')
plt.xlabel('$\lambda$')
plt.ylabel('Standardized coefficient')
plt.legend(train.columns.drop(['booking_status', 'Booking_ID', 'type_of_meal_plan', 'market_segment_type', 
                               'arrival_month', 'room_type_reserved']), loc='center left', bbox_to_anchor=(1, 0.5));

# %%
#Cross validation to find the optimal value of the tuning parameter - lambda
alphas = 10**np.linspace(1.5,-3,200)*0.5
ridgecv = RidgeCV(alphas = alphas,store_cv_values=True)
ridgecv.fit(Xstd, y)

#Optimal value of the tuning parameter - lambda
ridgecv.alpha_

# %%
#Using the developed ridge regression model to predict on test data
ridge = Ridge(alpha = ridgecv.alpha_)
ridge = ridge.fit(Xstd, y)

# %%
ridge_coeff = pd.DataFrame(ridge.coef_, columns = ['coefficients'])
ridge_coeff['predictors'] = X.columns
ridge_coeff

# %%
# Evaluating Model 6 on train data
confusion_matrix_data(Xstd, y, ridge, cutoff = 0.4)

# %%
# Evaluating Model 6 on test data
confusion_matrix_data(Xtest_std, test.booking_status, ridge, cutoff = 0.4)

# %%
#Predict the values using the ridge model
pred_values_6 = ridge.predict(Xtest_std)

# %% [markdown]
# ### Model 7) Lasso
# *By Hoda Fakhari*

# %%
# Model 7) Lasso

# %%
alphas = 10**np.linspace(10,-2,100)*0.1

#Finding the lasso coefficients for increasing values of the tuning parameter
lasso = Lasso(max_iter = 10000)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(Xstd, y)
    coefs.append(lasso.coef_)
    
#Visualizing the shrinkage in lasso coefficients with increasing values of the tuning parameter lambda
plt.xlabel('xlabel', fontsize=18)
plt.ylabel('ylabel', fontsize=18)
plt.plot(alphas, coefs)
plt.xscale('log')
plt.xlabel('$\lambda$')
plt.ylabel('Standardized coefficient')
plt.legend(train.columns.drop(['booking_status', 'Booking_ID', 'type_of_meal_plan', 'market_segment_type', 
                               'arrival_month', 'room_type_reserved']), loc='center left', bbox_to_anchor=(1, 0.5));

# %%
#Cross validation to find the optimal value of the tuning parameter - lambda
alphas = 10**np.linspace(-1,-5,200)*0.5
lassocv = LassoCV(alphas = alphas, cv = 10, max_iter = 100000)
lassocv.fit(Xstd, y)

#Optimal value of the tuning parameter - lamda
lassocv.alpha_

# %%
#Using the developed lasso model to predict on test data
lasso = Lasso(alpha = lassocv.alpha_)
lasso = lasso.fit(Xstd, y)

# %%
lasso_coeff = pd.DataFrame(lasso.coef_, columns = ['coefficients'])
lasso_coeff['predictors'] = X.columns
lasso_coeff

# %%
# Evaluating Model 7 on train data
confusion_matrix_data(Xstd, y, lasso, cutoff = 0.4)

# %%
# Evaluating Model 7 on test data
confusion_matrix_data(Xtest_std, test.booking_status, lasso, cutoff = 0.4)

# %%
#Predict the values using the lasso model
pred_values_7 = lasso.predict(Xtest_std)

# %% [markdown]
# ### Code fitting the final model
# *By Elena Llaguno Cantu*

# %% [markdown]
# Put the code(s) that fit the final model(s) in separate cell(s), i.e., the code with the `.ols()` or `.logit()` functions.

# %%
df = pd.DataFrame()
df['Model_1'] = pred_values_1
df['Model_2'] = pred_values_2
df['Model_3'] = pred_values_3
df['Model_4'] = pred_values_4
df['Model_5'] = pred_values_5
df['Model_6'] = pred_values_6
df['Model_7'] = pred_values_7

# %%
def applying_cutoff(df): 
    for col in df.columns:
        for index, value in df[col].iteritems():
            if value < 0.5:
                df.at[index, col] = 0
            else:
                df.at[index, col] = 1  
            
    return df

# %%
df = applying_cutoff(df)
df

# %%
# averaging the model results function
def combining_results(df): 
    df['sum'] = df.sum(axis=1)

    for index, row in df.iterrows():
        if row['sum'] >= 3:
            df.at[index, 'sum'] = 1
        else:
            df.at[index, 'sum'] = 0
        
    pred_values = df['sum']
    
    return pred_values

# %%
final_values = combining_results(df)
final_values

# %%
# Modified confusion matrix function

from sklearn.metrics import roc_curve, auc

def confusion_matrix_data_modified(pred_values,actual_values,cutoff=0.5):
# Specify the bins
    bins=np.array([0,cutoff,1])
#Confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
# Calculate the accuracy
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    fnr = (cm[1,0])/(cm[1,0]+cm[1,1])
    precision = (cm[1,1])/(cm[0,1]+cm[1,1])
    fpr = (cm[0,1])/(cm[0,0]+cm[0,1])
    tpr = (cm[1,1])/(cm[1,0]+cm[1,1])
    fpr_roc, tpr_roc, auc_thresholds = roc_curve(actual_values, pred_values)
    auc_value = (auc(fpr_roc, tpr_roc))# AUC of ROC
    sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
    plt.ylabel("Actual Values")
    plt.xlabel("Predicted Values")
    print("Classification accuracy = {:.1%}".format(accuracy))
    print("Precision = {:.1%}".format(precision))
    print("TPR or Recall = {:.1%}".format(tpr))
    print("FNR = {:.1%}".format(fnr))
    print("FPR = {:.1%}".format(fpr))
    print("ROC-AUC = {:.1%}".format(auc_value))

# %%
# Evaluating final model on test data
confusion_matrix_data_modified(final_values,test.booking_status,0.45)

# %% [markdown]
# ## Conclusions and Recommendations to stakeholder(s)
#
# You may or may not have code to put in this section. Delete this section if it is irrelevant.

# %% [markdown]
# ## Overbooking Formula

# %% [markdown]
# Currently, most hotels overbook anywhere between 2%, 3%, up to 10%, and 15%. The higher the overbooking percentage, the more likely a customer is to have to be rebooked to a different hotel. This would lead to customers dissatisfaction due to the constant moving pieces.
#
# The true positive rate is aroun 60%, which means that 60% of the customers predicted to cancel will cancel. To edge on the safer end, we would recommend overbooking approximately 50% the number of customers predicted to cancel for the night.
#
# In addition, the true negative rate or the specificity of the model is 1 - FPR = ~90%, which means that approximately 90% of customers predicted to not cancel follow through with their reservation. This means that using our model, we will miss guess around 10% of customers who are going to follow through. Once again, to edge on the safer end, we would recommend overbooking approximately 2% the number of customers predicted to follow through for the night. This would be best for the hotel to maximizes the profit.
#
# In addition, we would recommend that the customer round down the number of rooms to overbook, just to edge on the safer side

# %%
# Modified confusion matrix function

from sklearn.metrics import roc_curve, auc

def confusion_matrix_data_modified(pred_values,actual_values,cutoff=0.5):
# Specify the bins
    bins=np.array([0,cutoff,1])
#Confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
# Calculate the accuracy
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    fnr = (cm[1,0])/(cm[1,0]+cm[1,1])
    precision = (cm[1,1])/(cm[0,1]+cm[1,1])
    fpr = (cm[0,1])/(cm[0,0]+cm[0,1])
    tpr = (cm[1,1])/(cm[1,0]+cm[1,1])
    fpr_roc, tpr_roc, auc_thresholds = roc_curve(actual_values, pred_values)
    auc_value = (auc(fpr_roc, tpr_roc))# AUC of ROC
    sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
    plt.ylabel("Actual Values")
    plt.xlabel("Predicted Values")
    print("Classification accuracy = {:.1%}".format(accuracy))
    print("Precision = {:.1%}".format(precision))
    print("TPR or Recall = {:.1%}".format(tpr))
    print("FNR = {:.1%}".format(fnr))
    print("FPR = {:.1%}".format(fpr))
    print("ROC-AUC = {:.1%}".format(auc_value))

# %%
# Calling the function
confusion_matrix_data_modified(final_values,test.booking_status,0.45)

# %%
# Function to give a model's tpr

def confusion_matrix_data_modified_tpr(pred_values,actual_values,cutoff=0.5):
# Specify the bins
    bins=np.array([0,cutoff,1])
#Confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
# Calculate the accuracy
    tpr = (cm[1,1])/(cm[1,0]+cm[1,1])
    fpr_roc, tpr_roc, auc_thresholds = roc_curve(actual_values, pred_values)
    auc_value = (auc(fpr_roc, tpr_roc))# AUC of ROC
    return tpr

# %%
test_tpr = confusion_matrix_data_modified_tpr(final_values,test.booking_status,0.45)
test_tpr

# %%
# Function to give a model's tnr

def confusion_matrix_data_modified_tnr(pred_values,actual_values,cutoff=0.5):
# Specify the bins
    bins=np.array([0,cutoff,1])
#Confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
# Calculate the accuracy
    fpr = (cm[0,1])/(cm[0,0]+cm[0,1])
    tnr = 1 - fpr
    fpr_roc, tpr_roc, auc_thresholds = roc_curve(actual_values, pred_values)
    auc_value = (auc(fpr_roc, tpr_roc))# AUC of ROC
    return tnr

# %%
test_tnr = confusion_matrix_data_modified_tnr(final_values,test.booking_status,0.45)
test_tnr

# %%
test_0_1 = test.booking_status.value_counts()
test_0_1.head()

# %%
# Overbooking formula for the number of rooms they should overbook

import math

def overbooking_formula(tpr, tnr, test_0_1, test):
    min_price = test.avg_price_per_room.min()
    max_price = test.avg_price_per_room.max()
    overbooking = test_0_1[1] * (tpr - 0.1) + test_0_1[0] * (1 - tnr - 0.1)
    overbooking = math.floor(overbooking)
    lower = overbooking * min_price
    higher = overbooking * max_price
    print('The client should overbook', overbooking, 'rooms.')
    print('The client would save at least $', lower, ', but this number can also go up to $', higher)

# %%
overbooking_formula(test_tpr, test_tnr, test_0_1, test)
